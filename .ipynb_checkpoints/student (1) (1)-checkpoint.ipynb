# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# ### Background:

# %% [markdown]
# The real estate agency aims to provide accurate property valuations to homeowners looking to sell their homes and to buyers interested in purchasing properties. Property valuation is a critical aspect of real estate transactions as it directly impacts pricing decisions, marketing strategies, and negotiation outcomes. Business Problem Statement: The real estate agency faces challenges in accurately valuing properties, which can lead to overpricing or underpricing homes, affecting client satisfaction, time on market, and overall business performance.

# %% [markdown]
# ## Business Problem.

# %% [markdown]
# The real estate agency faces challenges in accurately valuing properties, which can lead to overpricing or underpricing homes, affecting client satisfaction, time on market, and overall business performance.

# %% [markdown]
# ## Importing relevant libraries

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import csv
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the kc_house_data datset

# %%
#lets load the data
m = r"C:\Users\Victor Keya\Documents\Flatiron\Phase2_project\dsc-phase-2-project-v2-3\data\kc_house_data.csv"
df = pd.read_csv(m)
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0          5650     1.0        NaN  NONE  ...      7 Average       1180
# 1          7242     2.0         NO  NONE  ...      7 Average       2170
# 2         10000     1.0         NO  NONE  ...  6 Low Average        770
# 3          5000     1.0         NO  NONE  ...      7 Average       1050
# 4          8080     1.0         NO  NONE  ...         8 Good       1680
# ...         ...     ...        ...   ...  ...            ...        ...
# 21592      1131     3.0         NO  NONE  ...         8 Good       1530
# 21593      5813     2.0         NO  NONE  ...         8 Good       2310
# 21594      1350     2.0         NO  NONE  ...      7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...         8 Good       1600
# 21596      1076     2.0         NO  NONE  ...      7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0     1955           0.0    98178  47.5112 -122.257
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 2                0.0     1933           NaN    98028  47.7379 -122.233
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# ...              ...      ...           ...      ...      ...      ...
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# The real estate agency's business problem revolves around advising provide accurate property valuations to homeowners looking to sell their homes and to buyers interested in purchasing properties. To address this, we will use regression modeling techniques to analyze the dataset and identify key factors influencing property prices, particularly focusing on:-
#
# •Property characteristics (e.g., bedrooms, bathrooms, square footage, lot size, floors)
#
# •Location attributes (e.g., zip code, latitude, longitude)
#
# •Property condition, grade, and view•Historical data (e.g., year built, year renovated)
#
# •Neighborhood factors (e.g., comparable sales data, school district ratings, amenities)
#
# We will explore features such as the number of bedrooms, bathrooms, square footage, floors, condition, grade, waterfront status,and potentially other relevant factors.

# %%
df.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 21592      1131     3.0         NO  NONE  ...     8 Good       1530
# 21593      5813     2.0         NO  NONE  ...     8 Good       2310
# 21594      1350     2.0         NO  NONE  ...  7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...     8 Good       1600
# 21596      1076     2.0         NO  NONE  ...  7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [5 rows x 21 columns]

# %%
df.sample()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 13732  3319500385  6/16/2014  400000.0         4       1.75         1580
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 13732      5340     1.0         NO  NONE  ...  7 Average       1130
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 13732          450.0     1947           0.0    98144  47.6003 -122.306
#
#        sqft_living15  sqft_lot15
# 13732            830         980
#
# [1 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(6), int64(9), object(6)
# memory usage: 3.5+ MB

# %% [markdown]
# Our dataset has 21597 rows and 21 columns. There are null values on the waterfront, yr_renovated columns. Data types in the data set include floats, integers and objects

# %% [markdown]
# ## DATA CLEANING

# %%
#lets make a copy of the dataset first
df.copy()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0          5650     1.0        NaN  NONE  ...      7 Average       1180
# 1          7242     2.0         NO  NONE  ...      7 Average       2170
# 2         10000     1.0         NO  NONE  ...  6 Low Average        770
# 3          5000     1.0         NO  NONE  ...      7 Average       1050
# 4          8080     1.0         NO  NONE  ...         8 Good       1680
# ...         ...     ...        ...   ...  ...            ...        ...
# 21592      1131     3.0         NO  NONE  ...         8 Good       1530
# 21593      5813     2.0         NO  NONE  ...         8 Good       2310
# 21594      1350     2.0         NO  NONE  ...      7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...         8 Good       1600
# 21596      1076     2.0         NO  NONE  ...      7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0     1955           0.0    98178  47.5112 -122.257
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 2                0.0     1933           NaN    98028  47.7379 -122.233
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# ...              ...      ...           ...      ...      ...      ...
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %% [markdown]
# The id columns seems not to be important, drop. Capitalise the column headings. Change the date format to dd/mm/yy. Put comas on the prices. Look at the data types, make sure they are correct.

# %%
#handling missing values.
#Lets first identify if we have null values
df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# id               0.000000
# date             0.000000
# price            0.000000
# bedrooms         0.000000
# bathrooms        0.000000
# sqft_living      0.000000
# sqft_lot         0.000000
# floors           0.000000
# waterfront       0.110015
# view             0.002917
# condition        0.000000
# grade            0.000000
# sqft_above       0.000000
# sqft_basement    0.000000
# yr_built         0.000000
# yr_renovated     0.177895
# zipcode          0.000000
# lat              0.000000
# long             0.000000
# sqft_living15    0.000000
# sqft_lot15       0.000000
# dtype: float64

# %% [markdown]
# The null values appear on the waterfront and yr_renovated columns. The percentages are small with the highest percentage being 17%. Normally if the percentage is small, we drop only the rows with the null values so as to keep as much data as possible for our study.

# %%
df = df.dropna()
df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# ...           ...         ...        ...       ...        ...          ...
# 21591  2997800021   2/19/2015   475000.0         3       2.50         1310
# 21592   263000018   5/21/2014   360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015   400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014   402101.0         2       0.75         1020
# 21596  1523300157  10/15/2014   325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...         grade sqft_above  \
# 1          7242     2.0         NO  NONE  ...     7 Average       2170
# 3          5000     1.0         NO  NONE  ...     7 Average       1050
# 4          8080     1.0         NO  NONE  ...        8 Good       1680
# 5        101930     1.0         NO  NONE  ...  11 Excellent       3890
# 6          6819     2.0         NO  NONE  ...     7 Average       1715
# ...         ...     ...        ...   ...  ...           ...        ...
# 21591      1294     2.0         NO  NONE  ...        8 Good       1180
# 21592      1131     3.0         NO  NONE  ...        8 Good       1530
# 21593      5813     2.0         NO  NONE  ...        8 Good       2310
# 21594      1350     2.0         NO  NONE  ...     7 Average       1020
# 21596      1076     2.0         NO  NONE  ...     7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# 5             1530.0     2001           0.0    98053  47.6561 -122.005
# 6                  ?     1995           0.0    98003  47.3097 -122.327
# ...              ...      ...           ...      ...      ...      ...
# 21591          130.0     2008           0.0    98116  47.5773 -122.409
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 1               1690        7639
# 3               1360        5000
# 4               1800        7503
# 5               4760      101930
# 6               2238        6819
# ...              ...         ...
# 21591           1330        1265
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21596           1020        1357
#
# [15762 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.shape
# Out:
# (15762, 21)

# %% [markdown]
# Our Dataset has 21 columns, 15762 rows and no missing values.

# %% [markdown]
# ### DROPPING IRRELEVANT VALUES

# %%
#dropping the ID column as it seems to be irrelevant
df = df.drop(columns=['id'])
df.head()
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1  12/9/2014   538000.0         3       2.25         2570      7242     2.0
# 3  12/9/2014   604000.0         4       3.00         1960      5000     1.0
# 4  2/18/2015   510000.0         3       2.00         1680      8080     1.0
# 5  5/12/2014  1230000.0         4       4.50         5420    101930     1.0
# 6  6/27/2014   257500.0         3       2.25         1715      6819     2.0
#
#   waterfront  view  condition         grade  sqft_above sqft_basement  \
# 1         NO  NONE    Average     7 Average        2170         400.0
# 3         NO  NONE  Very Good     7 Average        1050         910.0
# 4         NO  NONE    Average        8 Good        1680           0.0
# 5         NO  NONE    Average  11 Excellent        3890        1530.0
# 6         NO  NONE    Average     7 Average        1715             ?
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 1      1951        1991.0    98125  47.7210 -122.319           1690
# 3      1965           0.0    98136  47.5208 -122.393           1360
# 4      1987           0.0    98074  47.6168 -122.045           1800
# 5      2001           0.0    98053  47.6561 -122.005           4760
# 6      1995           0.0    98003  47.3097 -122.327           2238
#
#    sqft_lot15
# 1        7639
# 3        5000
# 4        7503
# 5      101930
# 6        6819

# %% [markdown]
# <strong>DUPLICATED VALUES

# %%
df.duplicated().any
# Out:
# <bound method Series.any of 1        False
# 3        False
# 4        False
# 5        False
# 6        False
#          ...
# 21591    False
# 21592    False
# 21593    False
# 21594    False
# 21596    False
# Length: 15762, dtype: bool>

# %% [markdown]
# We dont have any duplicated values

# %%
df.shape
# Out:
# (15762, 20)

# %% [markdown]
# <strong>CHANGING THE DATA TYPES

# %%
#The floors and yr_renovated data types need to be changed.
df['floors'] = df['floors'].astype(int)
#df['sqft_basement'] = df['sqft_basement'].astype(int)
df['yr_renovated'] = df['yr_renovated'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 1 to 21596
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           15762 non-null  object
#  1   price          15762 non-null  float64
#  2   bedrooms       15762 non-null  int64
#  3   bathrooms      15762 non-null  float64
#  4   sqft_living    15762 non-null  int64
#  5   sqft_lot       15762 non-null  int64
#  6   floors         15762 non-null  int32
#  7   waterfront     15762 non-null  object
#  8   view           15762 non-null  object
#  9   condition      15762 non-null  object
#  10  grade          15762 non-null  object
#  11  sqft_above     15762 non-null  int64
#  12  sqft_basement  15762 non-null  object
#  13  yr_built       15762 non-null  int64
#  14  yr_renovated   15762 non-null  int32
#  15  zipcode        15762 non-null  int64
#  16  lat            15762 non-null  float64
#  17  long           15762 non-null  float64
#  18  sqft_living15  15762 non-null  int64
#  19  sqft_lot15     15762 non-null  int64
# dtypes: float64(4), int32(2), int64(8), object(6)
# memory usage: 2.4+ MB

# %% [markdown]
# <strong>OUTLIERS

# %%
#Lets check to see if we have outliers
plt.figure(figsize=(12,6))

#create a boxplot of the dataframe
df.boxplot()
plt.xticks(rotation=45)
#Add a title to the plot
plt.title('DF Boxplot')

plt.show()

# %% [markdown]
# From the above analysis, we can see that outliers are on the price, sqft_lot and sqft_lot15columns. #Instead of dropping them, we consider replacing them with ...

# %%
df.price.skew()
# Out:
# 4.226727017501067

# %%
#We note that the columns Price,sqft_lot and sqft_lot15 have outliers
#Instead of dropping them, we consider replacing them with ...

# %% [markdown]
# <strong>REMOVING OUTLIERS

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\Victor Keya\Documents\Anaconda\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# Z SCORE METHOD

# %%
#find limits
upper_limit = df["price"].mean() + 3*df["price"].std()
lower_limit = df["price"].mean() - 3*df["price"].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 1657994.6919203326
# lower limit: -575360.3404420939

# %%
#find the outliers
df.loc[(df['price'] > upper_limit) | (df['price'] < lower_limit)]
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 21     8/26/2014  2000000.0         3       2.75         3050     44867
# 153     4/1/2015  2250000.0         4       3.25         5180     19850
# 246    9/29/2014  2400000.0         4       2.50         3650      8354
# 282    5/13/2015  2050000.0         5       3.00         3830      8480
# 300    6/24/2014  3080000.0         4       5.00         4550     18641
# ...          ...        ...       ...        ...          ...       ...
# 21367  9/23/2014  1770000.0         4       3.25         3980     10249
# 21457  11/1/2014  1750000.0         4       2.75         3560      8975
# 21524  1/13/2015  1880000.0         5       3.50         4410     13000
# 21552  1/30/2015  1700000.0         4       3.50         3830      8963
# 21560   1/7/2015  3570000.0         5       4.50         4850     10584
#
#        floors waterfront       view  condition         grade  sqft_above  \
# 21          1         NO  EXCELLENT    Average      9 Better        2330
# 153         2         NO       GOOD    Average     12 Luxury        3540
# 246         1        YES  EXCELLENT    Average      9 Better        1830
# 282         2         NO       FAIR  Very Good      9 Better        2630
# 300         1        YES  EXCELLENT    Average  10 Very Good        2600
# ...       ...        ...        ...        ...           ...         ...
# 21367       2         NO       NONE    Average  10 Very Good        3980
# 21457       2         NO       NONE    Average  10 Very Good        3560
# 21524       2         NO       GOOD    Average  10 Very Good        2920
# 21552       2         NO       NONE    Average  10 Very Good        3120
# 21560       2        YES  EXCELLENT    Average  10 Very Good        3540
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21            720.0      1968             0    98040  47.5316 -122.233
# 153          1640.0      2006             0    98006  47.5620 -122.162
# 246          1820.0      2000             0    98074  47.6338 -122.072
# 282          1200.0      1905          1994    98122  47.6166 -122.287
# 300          1950.0      2002             0    98074  47.6053 -122.077
# ...             ...       ...           ...      ...      ...      ...
# 21367           0.0      2011             0    98004  47.5873 -122.196
# 21457           0.0      2014             0    98004  47.6322 -122.209
# 21524        1490.0      2014             0    98006  47.5382 -122.111
# 21552         710.0      2014             0    98004  47.5990 -122.197
# 21560        1310.0      2007             0    98008  47.5943 -122.110
#
#        sqft_living15  sqft_lot15
# 21              4110       20336
# 153             3160        9750
# 246             3120       18841
# 282             3050        7556
# 300             4550       19508
# ...              ...         ...
# 21367           2450       10912
# 21457           3440       12825
# 21524           5790       12969
# 21552           2190       10777
# 21560           3470       18270
#
# [282 rows x 20 columns]

# %% [markdown]
# REMOVING OUTLIERS

# %%
#capping method , change the outlier values to upper or lower limit
new_df = df.copy()

# %%
new_df.head()
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1  12/9/2014   538000.0         3       2.25         2570      7242       2
# 3  12/9/2014   604000.0         4       3.00         1960      5000       1
# 4  2/18/2015   510000.0         3       2.00         1680      8080       1
# 5  5/12/2014  1230000.0         4       4.50         5420    101930       1
# 6  6/27/2014   257500.0         3       2.25         1715      6819       2
#
#   waterfront  view  condition         grade  sqft_above sqft_basement  \
# 1         NO  NONE    Average     7 Average        2170         400.0
# 3         NO  NONE  Very Good     7 Average        1050         910.0
# 4         NO  NONE    Average        8 Good        1680           0.0
# 5         NO  NONE    Average  11 Excellent        3890        1530.0
# 6         NO  NONE    Average     7 Average        1715             ?
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 1      1951          1991    98125  47.7210 -122.319           1690
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
# 5      2001             0    98053  47.6561 -122.005           4760
# 6      1995             0    98003  47.3097 -122.327           2238
#
#    sqft_lot15
# 1        7639
# 3        5000
# 4        7503
# 5      101930
# 6        6819

# %%
new_df.loc[(new_df['price']>upper_limit), 'price'] = upper_limit
new_df.loc[(new_df['price']<lower_limit), 'price'] = lower_limit

# %%
#Lets check to see if we have outliers
plt.figure(figsize=(12,6))

#create a boxplot of the dataframe
new_df.boxplot()
plt.xticks(rotation=45)
#Add a title to the plot
plt.title('New DF Boxplot')

plt.show()

# %%
sns.distplot(new_df['price'])
# Out:
# C:\Users\Victor Keya\Documents\Anaconda\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
#removing outliers for sqft_lot
#find limits
upper_limit = new_df["sqft_lot"].mean() + 3*new_df["sqft_lot"].std()
lower_limit = new_df["sqft_lot"].mean() - 3*new_df["sqft_lot"].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 140749.47137611514
# lower limit: -110187.82856428923

# %%
#find the outliers
new_df.loc[(new_df['sqft_lot'] > upper_limit) | (new_df['sqft_lot'] < lower_limit)]
# Out:
#              date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 145     12/3/2014   921500.0         4       2.50         3670    315374
# 199    10/14/2014   385000.0         3       1.75         1350    155073
# 238      7/1/2014   800000.0         3       3.50         3830    221284
# 380     9/16/2014   270000.0         2       1.50         1380    209959
# 411     7/16/2014   517534.0         2       1.00          833    143947
# ...           ...        ...       ...        ...          ...       ...
# 21074   5/15/2014   720000.0         3       2.50         3150    151588
# 21309  11/12/2014   659000.0         3       2.50         3090    384634
# 21328   8/22/2014  1490000.0         5       6.00         6880    279968
# 21335  10/21/2014   565000.0         2       1.75         1130    276170
# 21532   8/19/2014  1060000.0         2       1.50         2370    184231
#
#        floors waterfront  view condition          grade  sqft_above  \
# 145         2         NO  NONE      Good       9 Better        3670
# 199         1         NO  NONE      Good      7 Average        1350
# 238         2         NO  NONE   Average   10 Very Good        3530
# 380         1         NO  NONE      Poor  6 Low Average        1380
# 411         1         NO  NONE   Average         5 Fair         833
# ...       ...        ...   ...       ...            ...         ...
# 21074       2         NO  NONE   Average       9 Better        3150
# 21309       2         NO  NONE   Average         8 Good        3090
# 21328       2         NO  GOOD   Average      12 Luxury        4070
# 21335       1         NO  NONE   Average         8 Good        1130
# 21532       2         NO  NONE   Average   11 Excellent        2370
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 145             0.0      1994             0    98077  47.7421 -122.026
# 199             0.0      1969             0    98038  47.4058 -121.994
# 238           300.0      1993             0    98077  47.7641 -122.023
# 380             0.0      1954             0    98011  47.7461 -122.195
# 411             0.0      2006             0    98070  47.3889 -122.482
# ...             ...       ...           ...      ...      ...      ...
# 21074           0.0      2007             0    98024  47.5720 -121.926
# 21309           0.0      2007             0    98019  47.7072 -121.927
# 21328        2810.0      2007             0    98045  47.4624 -121.779
# 21335           0.0      2006             0    98022  47.2673 -122.027
# 21532           0.0      2005             0    98045  47.4543 -121.778
#
#        sqft_living15  sqft_lot15
# 145             2840       87991
# 199             1560       50965
# 238             2920      148539
# 380             3130       19868
# 411             1380      143947
# ...              ...         ...
# 21074           2410      208652
# 21309           2200      292645
# 21328           4690      256803
# 21335           2092      217800
# 21532           3860      151081
#
# [263 rows x 20 columns]

# %%
#capping method , change the outlier values to upper or lower limit
new_df2 = new_df.copy()

# %%
new_df2.loc[(new_df2['sqft_lot']>upper_limit), 'sqft_lot'] = upper_limit
new_df2.loc[(new_df2['sqft_lot']<lower_limit), 'sqft_lot'] = lower_limit

# %%
#Lets check to see if we have outliers
plt.figure(figsize=(12,6))

#create a boxplot of the dataframe
new_df2.boxplot()
plt.xticks(rotation=45)
#Add a title to the plot
plt.title('New DF2 Boxplot')

plt.show()

# %%
#removing outliers for sqft_lot15
#find limits
upper_limit = new_df2["sqft_lot15"].mean() + 3*new_df2["sqft_lot15"].std()
lower_limit = new_df2["sqft_lot15"].mean() - 3*new_df2["sqft_lot15"].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 96832.10573471023
# lower limit: -71031.2746219073

# %%
#find the outliers
new_df2.loc[(new_df2['sqft_lot15'] > upper_limit) | (new_df2['sqft_lot15'] < lower_limit)]
# Out:
#              date      price  bedrooms  bathrooms  sqft_living       sqft_lot  \
# 5       5/12/2014  1230000.0         4       4.50         5420  101930.000000
# 98      7/11/2014   314000.0         3       1.75         1810   41800.000000
# 147      8/6/2014   430000.0         2       2.50         2420   60984.000000
# 238      7/1/2014   800000.0         3       3.50         3830  140749.471376
# 411     7/16/2014   517534.0         2       1.00          833  140749.471376
# ...           ...        ...       ...        ...          ...            ...
# 21335  10/21/2014   565000.0         2       1.75         1130  140749.471376
# 21345   7/21/2014   472000.0         3       2.50         3800  104979.000000
# 21470   4/28/2015  1460000.0         4       4.00         4620  130208.000000
# 21509  11/24/2014  1450000.0         4       3.50         4300  108865.000000
# 21532   8/19/2014  1060000.0         2       1.50         2370  140749.471376
#
#        floors waterfront  view  condition         grade  sqft_above  \
# 5           1         NO  NONE    Average  11 Excellent        3890
# 98          1         NO  NONE  Very Good     7 Average        1210
# 147         2         NO  NONE    Average     7 Average        2420
# 238         2         NO  NONE    Average  10 Very Good        3530
# 411         1         NO  NONE    Average        5 Fair         833
# ...       ...        ...   ...        ...           ...         ...
# 21335       1         NO  NONE    Average        8 Good        1130
# 21345       2         NO  NONE    Average        8 Good        3210
# 21470       2         NO  NONE    Average  10 Very Good        4620
# 21509       2         NO  NONE    Average  11 Excellent        4300
# 21532       2         NO  NONE    Average  11 Excellent        2370
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 5            1530.0      2001             0    98053  47.6561 -122.005
# 98            600.0      1980             0    98038  47.4109 -121.958
# 147             0.0      2007             0    98027  47.5262 -121.943
# 238           300.0      1993             0    98077  47.7641 -122.023
# 411             0.0      2006             0    98070  47.3889 -122.482
# ...             ...       ...           ...      ...      ...      ...
# 21335           0.0      2006             0    98022  47.2673 -122.027
# 21345         590.0      2005             0    98045  47.4304 -121.841
# 21470           0.0      2014             0    98024  47.5885 -121.939
# 21509           0.0      2014             0    98074  47.6258 -122.005
# 21532           0.0      2005             0    98045  47.4543 -121.778
#
#        sqft_living15  sqft_lot15
# 5               4760      101930
# 98              1650      135036
# 147             1940      193842
# 238             2920      148539
# 411             1380      143947
# ...              ...         ...
# 21335           2092      217800
# 21345           2040      109771
# 21470           4620      131007
# 21509           4650      107498
# 21532           3860      151081
#
# [267 rows x 20 columns]

# %%
data = new_df2.copy()

# %%
#capping method , change the outlier values to upper or lower limit
data.loc[(data['sqft_lot15']>upper_limit), 'sqft_lot15'] = upper_limit
data.loc[(data['sqft_lot15']<lower_limit), 'sqft_lot15'] = lower_limit

# %%
#Lets check to see if we have outliers
plt.figure(figsize=(12,6))

#create a boxplot of the dataframe
data.boxplot()
plt.xticks(rotation=45)
#Add a title to the plot
plt.title('Data Boxplot')

plt.show()

# %% [markdown]
# <strong>FEATURE ENGINEERING

# %%
#Lets capitalise the column titles.
data.columns = [col.capitalize() for col in data.columns]
data.columns
# Out:
# Index(['Date', 'Price', 'Bedrooms', 'Bathrooms', 'Sqft_living', 'Sqft_lot',
#        'Floors', 'Waterfront', 'View', 'Condition', 'Grade', 'Sqft_above',
#        'Sqft_basement', 'Yr_built', 'Yr_renovated', 'Zipcode', 'Lat', 'Long',
#        'Sqft_living15', 'Sqft_lot15'],
#       dtype='object')

# %%
data.head()
# Out:
#         Date      Price  Bedrooms  Bathrooms  Sqft_living  Sqft_lot  Floors  \
# 1  12/9/2014   538000.0         3       2.25         2570    7242.0       2
# 3  12/9/2014   604000.0         4       3.00         1960    5000.0       1
# 4  2/18/2015   510000.0         3       2.00         1680    8080.0       1
# 5  5/12/2014  1230000.0         4       4.50         5420  101930.0       1
# 6  6/27/2014   257500.0         3       2.25         1715    6819.0       2
#
#   Waterfront  View  Condition         Grade  Sqft_above Sqft_basement  \
# 1         NO  NONE    Average     7 Average        2170         400.0
# 3         NO  NONE  Very Good     7 Average        1050         910.0
# 4         NO  NONE    Average        8 Good        1680           0.0
# 5         NO  NONE    Average  11 Excellent        3890        1530.0
# 6         NO  NONE    Average     7 Average        1715             ?
#
#    Yr_built  Yr_renovated  Zipcode      Lat     Long  Sqft_living15  \
# 1      1951          1991    98125  47.7210 -122.319           1690
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
# 5      2001             0    98053  47.6561 -122.005           4760
# 6      1995             0    98003  47.3097 -122.327           2238
#
#      Sqft_lot15
# 1   7639.000000
# 3   5000.000000
# 4   7503.000000
# 5  96832.105735
# 6   6819.000000

# %%
#checking for leading & trailing whitespaces and removing them in our datasets
[col.strip() for col in data.columns]
# Out:
# ['Date',
#  'Price',
#  'Bedrooms',
#  'Bathrooms',
#  'Sqft_living',
#  'Sqft_lot',
#  'Floors',
#  'Waterfront',
#  'View',
#  'Condition',
#  'Grade',
#  'Sqft_above',
#  'Sqft_basement',
#  'Yr_built',
#  'Yr_renovated',
#  'Zipcode',
#  'Lat',
#  'Long',
#  'Sqft_living15',
#  'Sqft_lot15']

# %%
# Lets make sure the date column is in dd/mm/yy format
data['Date'] = pd.to_datetime(data['Date'])

# Format the date column to dd/mm/yy format
data['Date'] = data['Date'].dt.strftime('%d/%m/%y')
data.head()
# Out:
#        Date      Price  Bedrooms  Bathrooms  Sqft_living  Sqft_lot  Floors  \
# 1  09/12/14   538000.0         3       2.25         2570    7242.0       2
# 3  09/12/14   604000.0         4       3.00         1960    5000.0       1
# 4  18/02/15   510000.0         3       2.00         1680    8080.0       1
# 5  12/05/14  1230000.0         4       4.50         5420  101930.0       1
# 6  27/06/14   257500.0         3       2.25         1715    6819.0       2
#
#   Waterfront  View  Condition         Grade  Sqft_above Sqft_basement  \
# 1         NO  NONE    Average     7 Average        2170         400.0
# 3         NO  NONE  Very Good     7 Average        1050         910.0
# 4         NO  NONE    Average        8 Good        1680           0.0
# 5         NO  NONE    Average  11 Excellent        3890        1530.0
# 6         NO  NONE    Average     7 Average        1715             ?
#
#    Yr_built  Yr_renovated  Zipcode      Lat     Long  Sqft_living15  \
# 1      1951          1991    98125  47.7210 -122.319           1690
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
# 5      2001             0    98053  47.6561 -122.005           4760
# 6      1995             0    98003  47.3097 -122.327           2238
#
#      Sqft_lot15
# 1   7639.000000
# 3   5000.000000
# 4   7503.000000
# 5  96832.105735
# 6   6819.000000

# %% [markdown]
# Now the date column is in date/month/year format.

# %%
# Lets try put commas on the price column
# data['Price'] = data['Price'].apply(lambda x: "{:,.0f}".format(x))
# data.head()

# %%
#data["Price"] = data["Price"].astype()

# %% [markdown]
# ### Using the Date Column to come up with a new column called seasons

# %%
# Convert 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Extract month to determine the season
data['Month'] = data['Date'].dt.month

# Define a function to map month to season
def get_season(month):
    if month in [12, 1, 2]:  # Winter: December, January, February
        return 'Winter'
    elif month in [3, 4, 5]:  # Spring: March, April, May
        return 'Spring'
    elif month in [6, 7, 8]:  # Summer: June, July, August
        return 'Summer'
    else:  # Fall: September, October, November
        return 'Fall'

# Apply the function to create the 'seasons' column
data['Seasons'] = data['Month'].apply(get_season)

# Drop the 'Month' column if not needed
data.drop('Month', axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 1 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           15762 non-null  datetime64[ns]
#  1   Price          15762 non-null  float64
#  2   Bedrooms       15762 non-null  int64
#  3   Bathrooms      15762 non-null  float64
#  4   Sqft_living    15762 non-null  int64
#  5   Sqft_lot       15762 non-null  float64
#  6   Floors         15762 non-null  int32
#  7   Waterfront     15762 non-null  object
#  8   View           15762 non-null  object
#  9   Condition      15762 non-null  object
#  10  Grade          15762 non-null  object
#  11  Sqft_above     15762 non-null  int64
#  12  Sqft_basement  15762 non-null  object
#  13  Yr_built       15762 non-null  int64
#  14  Yr_renovated   15762 non-null  int32
#  15  Zipcode        15762 non-null  int64
#  16  Lat            15762 non-null  float64
#  17  Long           15762 non-null  float64
#  18  Sqft_living15  15762 non-null  int64
#  19  Sqft_lot15     15762 non-null  float64
#  20  Seasons        15762 non-null  object
# dtypes: datetime64[ns](1), float64(6), int32(2), int64(6), object(6)
# memory usage: 2.5+ MB

# %%
data['Sqft_basement'].unique
# Out:
# <bound method Series.unique of 1         400.0
# 3         910.0
# 4           0.0
# 5        1530.0
# 6             ?
#           ...
# 21591     130.0
# 21592       0.0
# 21593       0.0
# 21594       0.0
# 21596       0.0
# Name: Sqft_basement, Length: 15762, dtype: object>

# %% [markdown]
# <strong> DATA VISUALIZATION.

# %%
data.corr()
# Out:
#                   Price  Bedrooms  Bathrooms  Sqft_living  Sqft_lot    Floors  \
# Price          1.000000  0.328635   0.540745     0.711695  0.126606  0.266989
# Bedrooms       0.328635  1.000000   0.512243     0.573575  0.054089  0.159783
# Bathrooms      0.540745  0.512243   1.000000     0.753846  0.105388  0.522435
# Sqft_living    0.711695  0.573575   0.753846     1.000000  0.235484  0.357742
# Sqft_lot       0.126606  0.054089   0.105388     0.235484  1.000000 -0.031619
# Floors         0.266989  0.159783   0.522435     0.357742 -0.031619  1.000000
# Sqft_above     0.620708  0.474272   0.685677     0.876176  0.242759  0.522831
# Yr_built       0.058171  0.153229   0.504841     0.314220  0.068835  0.578865
# Yr_renovated   0.123804  0.017430   0.046988     0.050232  0.006629 -0.014642
# Zipcode       -0.048493 -0.147255  -0.199625    -0.196537 -0.181291 -0.096711
# Lat            0.361104 -0.005917   0.029930     0.058394 -0.097495  0.036727
# Long           0.033588  0.129370   0.222755     0.239521  0.308706  0.164675
# Sqft_living15  0.625485  0.390720   0.569290     0.756676  0.236988  0.298564
# Sqft_lot15     0.120754  0.055554   0.102069     0.235202  0.857586 -0.036828
#
#                Sqft_above  Yr_built  Yr_renovated   Zipcode       Lat  \
# Price            0.620708  0.058171      0.123804 -0.048493  0.361104
# Bedrooms         0.474272  0.153229      0.017430 -0.147255 -0.005917
# Bathrooms        0.685677  0.504841      0.046988 -0.199625  0.029930
# Sqft_living      0.876176  0.314220      0.050232 -0.196537  0.058394
# Sqft_lot         0.242759  0.068835      0.006629 -0.181291 -0.097495
# Floors           0.522831  0.578865     -0.014642 -0.096711  0.036727
# Sqft_above       1.000000  0.418850      0.018888 -0.257359  0.009045
# Yr_built         0.418850  1.000000     -0.223541 -0.344252 -0.144089
# Yr_renovated     0.018888 -0.223541      1.000000  0.068396  0.032126
# Zipcode         -0.257359 -0.344252      0.068396  1.000000  0.267763
# Lat              0.009045 -0.144089      0.032126  0.267763  1.000000
# Long             0.342034  0.408623     -0.070677 -0.562154 -0.133840
# Sqft_living15    0.732636  0.322190     -0.005688 -0.280086  0.047319
# Sqft_lot15       0.244759  0.082115      0.007216 -0.196315 -0.099546
#
#                    Long  Sqft_living15  Sqft_lot15
# Price          0.033588       0.625485    0.120754
# Bedrooms       0.129370       0.390720    0.055554
# Bathrooms      0.222755       0.569290    0.102069
# Sqft_living    0.239521       0.756676    0.235202
# Sqft_lot       0.308706       0.236988    0.857586
# Floors         0.164675       0.298564   -0.036828
# Sqft_above     0.342034       0.732636    0.244759
# Yr_built       0.408623       0.322190    0.082115
# Yr_renovated  -0.070677      -0.005688    0.007216
# Zipcode       -0.562154      -0.280086   -0.196315
# Lat           -0.133840       0.047319   -0.099546
# Long           1.000000       0.339699    0.330009
# Sqft_living15  0.339699       1.000000    0.271616
# Sqft_lot15     0.330009       0.271616    1.000000

# %%
Y = data['Price']
X = data['Sqft_living']
plt.scatter(X,Y)
plt.xlabel("INDEPENDENT VARIABLES")
plt.ylabel("DEPENDENT VARIABLES")
plt.show;

# %% [markdown]
# The relationship between Price and Sqft_living is linear but not perfectly linear

# %%
# Convert 'Seasons' column to categorical type to maintain the order of seasons in plots
data['Seasons'] = pd.Categorical(data['Seasons'], categories=['Spring', 'Summer', 'Fall', 'Winter'], ordered=True)

# Bar Plot: Count of purchases or renovations in each season
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Seasons')
plt.title('Count of Purchases or Renovations by Season')
plt.xlabel('Seasons')
plt.ylabel('Count')
plt.show()

# Box Plot: Housing prices or sizes across different seasons
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Seasons', y='Price')
plt.title('Housing Prices by Season')
plt.xlabel('Seasons')
plt.ylabel('Price')
plt.show()

# Another example: Box Plot for Sqft_living
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Seasons', y='Sqft_living')
plt.title('Sqft_living by Season')
plt.xlabel('Seasons')
plt.ylabel('Sqft_living')
plt.show()

# %% [markdown]
# Most House Purchases happen during summer season, with the least purchases happening in Winter season.

# %%
data
# Out:
#             Date      Price  Bedrooms  Bathrooms  Sqft_living  Sqft_lot  \
# 1     2014-09-12   538000.0         3       2.25         2570    7242.0
# 3     2014-09-12   604000.0         4       3.00         1960    5000.0
# 4     2015-02-18   510000.0         3       2.00         1680    8080.0
# 5     2014-12-05  1230000.0         4       4.50         5420  101930.0
# 6     2014-06-27   257500.0         3       2.25         1715    6819.0
# ...          ...        ...       ...        ...          ...       ...
# 21591 2015-02-19   475000.0         3       2.50         1310    1294.0
# 21592 2014-05-21   360000.0         3       2.50         1530    1131.0
# 21593 2015-02-23   400000.0         4       2.50         2310    5813.0
# 21594 2014-06-23   402101.0         2       0.75         1020    1350.0
# 21596 2014-10-15   325000.0         2       0.75         1020    1076.0
#
#        Floors Waterfront  View  Condition  ... Sqft_above  Sqft_basement  \
# 1           2         NO  NONE    Average  ...       2170          400.0
# 3           1         NO  NONE  Very Good  ...       1050          910.0
# 4           1         NO  NONE    Average  ...       1680            0.0
# 5           1         NO  NONE    Average  ...       3890         1530.0
# 6           2         NO  NONE    Average  ...       1715              ?
# ...       ...        ...   ...        ...  ...        ...            ...
# 21591       2         NO  NONE    Average  ...       1180          130.0
# 21592       3         NO  NONE    Average  ...       1530            0.0
# 21593       2         NO  NONE    Average  ...       2310            0.0
# 21594       2         NO  NONE    Average  ...       1020            0.0
# 21596       2         NO  NONE    Average  ...       1020            0.0
#
#       Yr_built  Yr_renovated  Zipcode      Lat     Long  Sqft_living15  \
# 1         1951          1991    98125  47.7210 -122.319           1690
# 3         1965             0    98136  47.5208 -122.393           1360
# 4         1987             0    98074  47.6168 -122.045           1800
# 5         2001             0    98053  47.6561 -122.005           4760
# 6         1995             0    98003  47.3097 -122.327           2238
# ...        ...           ...      ...      ...      ...            ...
# 21591     2008             0    98116  47.5773 -122.409           1330
# 21592     2009             0    98103  47.6993 -122.346           1530
# 21593     2014             0    98146  47.5107 -122.362           1830
# 21594     2009             0    98144  47.5944 -122.299           1020
# 21596     2008             0    98144  47.5941 -122.299           1020
#
#          Sqft_lot15  Seasons
# 1       7639.000000     Fall
# 3       5000.000000     Fall
# 4       7503.000000   Winter
# 5      96832.105735   Winter
# 6       6819.000000   Summer
# ...             ...      ...
# 21591   1265.000000   Winter
# 21592   1509.000000   Spring
# 21593   7200.000000   Winter
# 21594   2007.000000   Summer
# 21596   1357.000000     Fall
#
# [15762 rows x 21 columns]

# %%
import statsmodels.api as sm
X = data[['Bedrooms', 'Bathrooms', 'Sqft_living', 'Sqft_lot', 'Floors',
        'Yr_built', 'Yr_renovated', 'Zipcode', 'Lat', 'Long',
        'Sqft_living15', 'Sqft_lot15']]
y = data['Price']

# Add a constant term to the independent variables (required for statsmodels)
X = sm.add_constant(X)

# Fit the multiple linear regression model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     2749.
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):               0.00
# Time:                        18:35:16   Log-Likelihood:            -2.1228e+05
# No. Observations:               15762   AIC:                         4.246e+05
# Df Residuals:                   15749   BIC:                         4.247e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.445e+07   2.84e+06     -5.092      0.000      -2e+07   -8.89e+06
# Bedrooms      -3.458e+04   1838.671    -18.807      0.000   -3.82e+04    -3.1e+04
# Bathrooms      4.792e+04   3191.198     15.015      0.000    4.17e+04    5.42e+04
# Sqft_living     170.3586      3.071     55.477      0.000     164.339     176.378
# Sqft_lot          0.4310      0.123      3.490      0.000       0.189       0.673
# Floors         4.351e+04   3304.774     13.165      0.000     3.7e+04       5e+04
# Yr_built      -2105.5044     69.260    -30.400      0.000   -2241.261   -1969.747
# Yr_renovated     28.7708      3.607      7.977      0.000      21.701      35.841
# Zipcode        -435.6938     32.415    -13.441      0.000    -499.230    -372.157
# Lat            6.181e+05   1.04e+04     59.151      0.000    5.98e+05    6.39e+05
# Long          -2.605e+05   1.28e+04    -20.276      0.000   -2.86e+05   -2.35e+05
# Sqft_living15   111.5963      3.201     34.868      0.000     105.323     117.870
# Sqft_lot15       -0.6080      0.177     -3.428      0.001      -0.956      -0.260
# ==============================================================================
# Omnibus:                     3392.553   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13169.077
# Skew:                           1.031   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                     2.08e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data
# Out:
#             Date      Price  Bedrooms  Bathrooms  Sqft_living  Sqft_lot  \
# 1     2014-09-12   538000.0         3       2.25         2570    7242.0
# 3     2014-09-12   604000.0         4       3.00         1960    5000.0
# 4     2015-02-18   510000.0         3       2.00         1680    8080.0
# 5     2014-12-05  1230000.0         4       4.50         5420  101930.0
# 6     2014-06-27   257500.0         3       2.25         1715    6819.0
# ...          ...        ...       ...        ...          ...       ...
# 21591 2015-02-19   475000.0         3       2.50         1310    1294.0
# 21592 2014-05-21   360000.0         3       2.50         1530    1131.0
# 21593 2015-02-23   400000.0         4       2.50         2310    5813.0
# 21594 2014-06-23   402101.0         2       0.75         1020    1350.0
# 21596 2014-10-15   325000.0         2       0.75         1020    1076.0
#
#        Floors Waterfront  View  Condition  ... Sqft_above  Sqft_basement  \
# 1           2         NO  NONE    Average  ...       2170          400.0
# 3           1         NO  NONE  Very Good  ...       1050          910.0
# 4           1         NO  NONE    Average  ...       1680            0.0
# 5           1         NO  NONE    Average  ...       3890         1530.0
# 6           2         NO  NONE    Average  ...       1715              ?
# ...       ...        ...   ...        ...  ...        ...            ...
# 21591       2         NO  NONE    Average  ...       1180          130.0
# 21592       3         NO  NONE    Average  ...       1530            0.0
# 21593       2         NO  NONE    Average  ...       2310            0.0
# 21594       2         NO  NONE    Average  ...       1020            0.0
# 21596       2         NO  NONE    Average  ...       1020            0.0
#
#       Yr_built  Yr_renovated  Zipcode      Lat     Long  Sqft_living15  \
# 1         1951          1991    98125  47.7210 -122.319           1690
# 3         1965             0    98136  47.5208 -122.393           1360
# 4         1987             0    98074  47.6168 -122.045           1800
# 5         2001             0    98053  47.6561 -122.005           4760
# 6         1995             0    98003  47.3097 -122.327           2238
# ...        ...           ...      ...      ...      ...            ...
# 21591     2008             0    98116  47.5773 -122.409           1330
# 21592     2009             0    98103  47.6993 -122.346           1530
# 21593     2014             0    98146  47.5107 -122.362           1830
# 21594     2009             0    98144  47.5944 -122.299           1020
# 21596     2008             0    98144  47.5941 -122.299           1020
#
#          Sqft_lot15  Seasons
# 1       7639.000000     Fall
# 3       5000.000000     Fall
# 4       7503.000000   Winter
# 5      96832.105735   Winter
# 6       6819.000000   Summer
# ...             ...      ...
# 21591   1265.000000   Winter
# 21592   1509.000000   Spring
# 21593   7200.000000   Winter
# 21594   2007.000000   Summer
# 21596   1357.000000     Fall
#
# [15762 rows x 21 columns]
